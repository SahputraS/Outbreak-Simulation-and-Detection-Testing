# %% [markdown]
# <a href="https://colab.research.google.com/github/SahputraS/Outbreak-Simulation-and-Detection-Testing/blob/main/Endemic_Label_MG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download the packages if not already available
packages_needed <- c("mem", "ggTimeSeries", "fuzzyjoin", "zoo", "yardstick", "purrr", "plotly")
packages_to_install <- packages_needed[!(packages_needed %in% installed.packages()[,"Package"])]

if(length(packages_to_install)) {
  install.packages(packages_to_install)
}
lapply(packages_needed, library, character.only = TRUE)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘nortest’, ‘sp’, ‘sparsevctrs’, ‘sm’, ‘mclust’, ‘RcppRoll’, ‘EnvStats’, ‘stringdist’, ‘geosphere’, ‘hardhat’, ‘lazyeval’, ‘crosstalk’
#
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
# [[1]]
# [1] "mem"       "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
#  [1] "ggTimeSeries" "ggplot2"      "mem"          "stats"        "graphics"
#  [6] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[3]]
#  [1] "fuzzyjoin"    "ggTimeSeries" "ggplot2"      "mem"          "stats"
#  [6] "graphics"     "grDevices"    "utils"        "datasets"     "methods"
# [11] "base"
#
# [[4]]
#  [1] "zoo"          "fuzzyjoin"    "ggTimeSeries" "ggplot2"      "mem"
#  [6] "stats"        "graphics"     "grDevices"    "utils"        "datasets"
# [11] "methods"      "base"
#
# [[5]]
#  [1] "yardstick"    "zoo"          "fuzzyjoin"    "ggTimeSeries" "ggplot2"
#  [6] "mem"          "stats"        "graphics"     "grDevices"    "utils"
# [11] "datasets"     "methods"      "base"
#
# [[6]]
#  [1] "purrr"        "yardstick"    "zoo"          "fuzzyjoin"    "ggTimeSeries"
#  [6] "ggplot2"      "mem"          "stats"        "graphics"     "grDevices"
# [11] "utils"        "datasets"     "methods"      "base"
#
# [[7]]
#  [1] "plotly"       "purrr"        "yardstick"    "zoo"          "fuzzyjoin"
#  [6] "ggTimeSeries" "ggplot2"      "mem"          "stats"        "graphics"
# [11] "grDevices"    "utils"        "datasets"     "methods"      "base"

# %%
library(readxl)
library(stringi)

library(dplyr)
library(ggplot2)
library(tidyr)
library(tibble)

library(lubridate)

library(ggTimeSeries)
library(readr)
library(fuzzyjoin)

library(mem)
library(zoo)
library(yardstick)

library(purrr)
library(plotly)
library(htmlwidgets)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
#
# Attaching package: ‘readr’
#
#
# The following object is masked from ‘package:yardstick’:
#
#     spec

# %% [markdown]
# ## Upload Infodengue data

# %%
library(googledrive)
library(googlesheets4)
# Out:
# Attaching package: ‘googlesheets4’
#
#
# The following objects are masked from ‘package:googledrive’:
#
#     request_generate, request_make

# %%
# Save cache in a file so that i don't have to authenticate repeatedly
drive_auth(cache = "/content/drive/My Drive/.secrets", use_oob = TRUE)
# Out:
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=d29130aec06849697c7d4ce6ebb46d71&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQWZySWVwQmVMeWhqSzN3UkpyOExvYkdfeWlFMEt4T3pzc2FPMEtyb3doWExJMlVPaHFySk51ZmlhTzdTTW5sOWFEVHNqZyIsInN0YXRlIjoiZDI5MTMwYWVjMDY4NDk2OTdjN2Q0Y2U2ZWJiNDZkNzEifQ==

# %% [markdown]
# ## Donwload InfoDengue on Target Municipalities

# %%
# drv_file <- drive_get("GISAID/data_sp_incidence_target.csv")  # a Drive *file*, not a local path
# drive_download(file = drv_file, path = "data_sp_incidence_target.csv", overwrite = TRUE)

# data <- read_csv("data_sp_incidence_target.csv")

# %%
get_alert_periods <- function(df) {
  df <- df %>%
    arrange(data_iniSE) %>%
    mutate(change = (nivel != lag(nivel, default = first(nivel))),
           group = cumsum(change))

  df %>%
    group_by(group, nivel) %>%
    summarise(start = min(data_iniSE),
              end = max(data_iniSE),
              .groups = "drop")
}

# %%
download_data <- function(geocode,
                              ew_start = 1, ew_end = 52,
                              ey_start = 2010, ey_end = 2025){
  url <- "https://info.dengue.mat.br/api/alertcity?"
  cons <- paste0(url,
                 "geocode=", geocode,
                 "&disease=dengue",
                 "&format=csv",
                 "&ew_start=", ew_start,
                 "&ew_end=", ew_end,
                 "&ey_start=", ey_start,
                 "&ey_end=", ey_end)

  dados <- read_csv(cons, show_col_types = FALSE) %>% arrange(data_iniSE)
  dados$ibge <- geocode
  dados$rate_pop <- dados$casos / dados$pop * 100000

  return (dados)}

# %%
plot_data <- function(dados, city_name, to_plot) {

  alert_df <- get_alert_periods(dados)

  nivel_colors <- c(
    "1" = "#a8ddb5",
    "2" = "#fdd49e",
    "3" = "#fdae61",
    "4" = "#ef6548"
  )

  options(repr.plot.width = 20, repr.plot.height = 8)
  p <- ggplot() +
    geom_col(data = dados %>% filter(nivel %in% c(1, 2, 3, 4)),
            aes(x = data_iniSE, y = .data[[to_plot]], fill = factor(nivel)),
            width = 7, alpha = 1) +
    geom_line(data = dados, aes(x = data_iniSE, y = .data[[to_plot]]),
              color = "black", size = 1) +
    scale_fill_manual(values = nivel_colors, name = "Alert Level") +
    labs(
      title = paste("Approximated Dengue Cases —", city_name),
      x = "Year",
      y = "Number of Cases per 100K pop"
    ) +
    scale_x_date(date_breaks = "1 year", date_labels = "%Y") +
    theme_light() +
    theme(
      plot.title = element_text(size = 20, face = "bold", hjust = 0),
      axis.text.x = element_text(angle = 0, hjust = 0.5, size = 20),
      axis.text.y = element_text(size = 20),
      axis.title = element_text(size = 20),
      legend.position = "right",
      legend.text = element_text(size = 20),
      legend.title = element_text(size = 20)
    )

  return(p)
}

# %%
# Get the geocodes where dengue exists on GISAID data
drv_file <- drive_get("GISAID/mg_gisaid_geocode.csv")
drive_download(file = drv_file, path = "mg_gisaid_geocode.csv", overwrite = TRUE)

target_geocode <- read_csv("mg_gisaid_geocode.csv", show_col_types = FALSE)
codes <- target_geocode %>% pull(2) %>% as.integer()
# Out:
# ✔ The input `path` resolved to exactly 1 file.
#
# File downloaded:
#
# • mg_gisaid_geocode.csv <id: 1ZVN7szoWcARzOPMDHa9__VQOR5Nowiip>
#
# Saved locally as:
#
# • mg_gisaid_geocode.csv

# %%
length(codes)
# Out:
# [1] 93

# %%
# Donwload only the municipalities that exists on GISAID data
dd <- vector("list", length(codes))
for (i in seq_along(codes)) {
  ib <- as.integer(codes[i])
  dd[[i]] <- download_data(ib) %>%
    select(data_iniSE, casos, pop, nivel, ibge, rate_pop)
}
mg_data <- bind_rows(dd)

# %%
head(mg_data,3)
# Out:
#   data_iniSE casos pop    nivel ibge    rate_pop
# 1 2010-01-03 1     168641 1     3151800 0.5929756
# 2 2010-01-10 0     168641 1     3151800 0.0000000
# 3 2010-01-17 0     168641 1     3151800 0.0000000

# %%
#Sample output
plot_data(mg_data %>% filter(ibge == 3106200), 'Belo Horizonte', 'rate_pop')
# Out:
# plot without title

# %%
# Check if the data is complete
full_dates <- seq(min(mg_data$data_iniSE), max(mg_data$data_iniSE), by = "1 week")

check_missing_date <- mg_data %>%
  group_by(ibge) %>%
  complete(data_iniSE = full_dates) %>%
  filter(is.na(casos)) %>%
  select(ibge, data_iniSE) %>%
  ungroup()

# %%
check_missing_date %>% select(data_iniSE) %>% unique
# Out:
#   data_iniSE
# 1 2018-04-08

# %%
# There is the mismatch of date, the 2018-04-01 is wednesday, not the typical sunday
mg_data %>% filter(data_iniSE >= '2018-03-25' & data_iniSE <= '2018-04-22') %>% select (data_iniSE) %>% unique
# Out:
#   data_iniSE
# 1 2018-03-25
# 2 2018-04-01
# 3 2018-04-04
# 4 2018-04-15
# 5 2018-04-22

# %%
# sp_city_data1 <- mg_data %>% filter(ibge == 3527900) %>% filter(data_iniSE <= as.Date('2023-08-01') & data_iniSE >= as.Date('2010-08-01'))
# plot_data(sp_city_data1, '3549508', 'rate_pop')

# %%
# sp_city_data1 <- mg_data %>% filter(ibge ==  3514403) %>% filter(data_iniSE > as.Date('2023-08-01'))
# plot_data(sp_city_data1 , 'sao paulo', 'rate_pop')

# %%
seasoned <- function (inc_data, mon_start, zero_run_weeks = 8L){

# Make seasons, each seasons start is August
inc_data <- inc_data %>%
  mutate(
    week   = isoweek(data_iniSE),
    season = if_else(month(data_iniSE) >= mon_start, year(data_iniSE) + 1L, year(data_iniSE))
  )

# Make index of the season
inc_data <- inc_data %>%
  filter(season != 2010) %>%
  mutate(
    season_start = make_date(season - 1L, mon_start, 1),
    t_in_season  = as.integer((as.Date(data_iniSE) - season_start) / 7) + 1L
  )

## Make the full dates
full_dates <- tibble(
  data_iniSE = seq(
    floor_date(min(inc_data$data_iniSE), "week", week_start = 7),
    floor_date(max(inc_data$data_iniSE), "week", week_start = 7),
    by = "1 week"
  )
)

# CHeck gaps, first make sure all the data are on sunday (just in case)
inc_data <- inc_data %>%
  mutate(
    data_iniSE = as.Date(data_iniSE),
    sunday = floor_date(data_iniSE, "week", week_start = 1) + days(6)
  ) %>%
  arrange(data_iniSE) %>%
  group_by(sunday) %>%
  slice_tail(n = 1) %>%
  ungroup() %>%
  mutate(data_iniSE = sunday) %>%
  select(-sunday)

data_ori <- inc_data

# Check the missing week and do NA interpolation
inc_data <- full_join(full_dates, inc_data, by = "data_iniSE") %>% arrange(data_iniSE)

inc_data <-  inc_data %>%
  arrange(data_iniSE) %>%
  mutate(rate_pop = na.approx(rate_pop, na.rm = FALSE)) %>%
  fill(ibge, .direction = "down")

# Check long zeroes, if too long (6 moths and more then drop the season)
 bad_seasons <- inc_data %>%
    mutate(mm = month(data_iniSE)) %>%
    filter(mm >= 1, mm <= 6) %>% #focus on the peak months (jan - june)
    group_by(season) %>%
    summarise(
      max_zero_run = {
        v <- rate_pop
        z <- is.finite(v) & (v == 0)
        r <- rle(z)
        if (!length(r$lengths)) 0L else max(ifelse(r$values, r$lengths, 0L))
      },
      .groups = "drop"
    ) %>%
    filter(max_zero_run >= zero_run_weeks) %>%
    pull(season)

  if (length(bad_seasons)) {
    inc_data <- inc_data %>% filter(!(season %in% bad_seasons))
  }

sp_wide <- inc_data %>%
  select(season, t_in_season, rate_pop) %>% #here use the rate_population for data
  pivot_wider(names_from = season, values_from = rate_pop, names_prefix = "season_") %>%
  # filter(t_in_season <= 52) %>% # Remove week 53
  arrange(t_in_season) %>%
  # select(-t_in_season, -season_2026)
  select(-any_of(c("t_in_season", "season_2026")))


return(list(long = inc_data, wide = sp_wide, ori = data_ori))
}

# %%
# ss_res <- seasoned(mg_data %>% filter(ibge == 3549508), 5)
# wide_df <- ss_res$wide

# %% [markdown]
# ## Take typical seasons (sesons when dengue is not exploded nor when 'nothing' happened)

# %%
typical_seasons <- function (df_data, p_lo, p_hi){

  # Get Peaks
  peaks_df  = df_data %>% summarise(across(everything(), ~ suppressWarnings(max(.x, na.rm = TRUE))))
  peaks = as.numeric(peaks_df[1, ])
  geom_mean = exp(mean(log(peaks)))

  # Compute the quantiles
  peaks_df <- peaks_df/ geom_mean
  lo <- quantile(peaks_df, probs = p_lo, na.rm = TRUE)
  hi <- quantile(peaks_df, probs = p_hi, na.rm = TRUE)

  hi_cols <- peaks_df %>% select(where(~ any(.x >= hi, na.rm = TRUE))) %>% names()
  lo_cols <- peaks_df %>% select(where(~ any(.x <= lo, na.rm = TRUE))) %>% names()

  # cat(" remove the high outlier", hi_cols, "and remove the low outlier", lo_cols,"\n")

  # Remove outliers
  df_data <- df_data %>% select(-all_of(hi_cols), -all_of(lo_cols))

  if (ncol(df_data) < 5) {
    print("Removed too many columns")
    return(NULL)
  }

return (df_data)
}

# %%
run_mem <- function(train_df){

fit <- memmodel(train_df, i.seasons = ncol(train_df), i.method=4)
thr <- fit$pre.post.intervals

return (thr)
}

# %%
consec_check <- function(states, min_run = 3L, bridge = 0L) {
  s <- as.character(states)
  b <- s == "outbreak"   # logical vector (raw outbreaks)

  # Minimal weeks of consecutive outbreak to be considered real outbreak
  r1 <- rle(b)
  short_true <- r1$values & r1$lengths < min_run
  if (any(short_true)) r1$values[short_true] <- FALSE
  b1 <- inverse.rle(r1)

  # If there is a minimal 'endemic' between consecutive outbreak, then mark as outbreak as well
  if (bridge > 0L) {
    r2 <- rle(b1)
    n  <- length(r2$values)
    idx <- which(!r2$values & r2$lengths <= bridge)
    # only endemic gaps strictly between two outbreak runs
    idx <- idx[idx > 1 & idx < n & r2$values[idx - 1] & r2$values[idx + 1]]

    if (length(idx)) {
      r2$values[idx] <- TRUE
      b1 <- inverse.rle(r2)
    }
  }

  ifelse(b1, "outbreak", "endemic")
}

# %%
# x2 <- c("outbreak", "outbreak", "outbreak", "outbreak","endemic","endemic","outbreak","outbreak","outbreak","outbreak","endemic", "endemic", "outbreak", "endemic", "outbreak")
# consec_check(x2, min_run = 4, bridge = 2)

# %%
mem_label <- function(x, thr_pre, thr_post) {

  state <- "endemic"
  out   <- character(length(x))

  for (i in seq_along(x)) {
    val <- x[i]

    if (state == "endemic") {
      if (val >= thr_pre) {
        state <- "outbreak"
      }
    } else if (state == "outbreak") {
      if (val < thr_post) {
        state <- "endemic"
      }
    }

    out[i] <- state
  }

  return (consec_check(out, min_run = 3, bridge = 2))

}

# %%
preprocess <- function(df_data, mon_start = 8L, p_lo = 0.1, p_hi = 0.85) {

  ibges <- unique(df_data$ibge)

  thr_df     <- tibble()
  wide_all   <- vector("list", length(ibges))
  long_all   <- vector("list", length(ibges))
  mem_labs   <- vector("list", length(ibges))
  skipped  <- character(0)

  names(wide_all) <- names(long_all) <- names(mem_labs) <- as.character(ibges)
  i = 0

   # For each municipality, do
  for (ib in ibges) {
    i = i+1
    cat("run", ib, "\n")

    df_ib <- df_data %>% filter(ibge == ib)

    # Seasonize
    ss_res  <- seasoned(df_ib, mon_start)
    wide_df <- ss_res$wide
    long_df <- if (!is.null(ss_res$long)) ss_res$long else ss_res$indexed

    ori_df <- ss_res$ori

    wide_all[[as.character(ib)]] <- wide_df

    # pick typical seasons
    train_wide <- typical_seasons(wide_df, p_lo = p_lo, p_hi = p_hi)
    if (is.null(train_wide)) {
      skipped <- c(skipped, as.character(ib))
      next
    }

    # run MEM
    mem_res <- run_mem(train_wide)

    # thresholds extraction
    thr_pre  <- as.numeric(mem_res[[5]])
    thr_post <- as.numeric(mem_res[[6]])

    # append thresholds as rows
    thr_df <- bind_rows(thr_df, tibble(ibge = ib, pre = thr_pre, post = thr_post))

    # label based on threshold
    long_2 <- ori_df %>% arrange(data_iniSE) %>% mutate(mem_status = mem_label(rate_pop, thr_pre, thr_post))
    long_all[[as.character(ib)]] <- long_2
    cat('Total municipality processed', i)
    }

  return(list(thr_df = thr_df, res = long_all, train_wide = wide_all, skipped = skipped))
}

# %%
res_all <- preprocess(mg_data)
# Out:
# run 3151800
# Total municipality processed 1run 3162005
# Total municipality processed 2run 3106200
# Total municipality processed 3run 3118304
# Total municipality processed 4run 3136702
# Total municipality processed 5run 3170107
# Total municipality processed 6run 3118007
# Total municipality processed 7run 3162500
# Total municipality processed 8run 3145604
# Total municipality processed 9run 3118601
# Total municipality processed 10run 3154606
# Total municipality processed 11run 3124104
# Total municipality processed 12run 3150406
# [1] "Removed too many columns"
# run 3134608
# Total municipality processed 14run 3165537
# Total municipality processed 15run 3146107
# Total municipality processed 16run 3106705
# Total municipality processed 17run 3143906
# Total municipality processed 18run 3119302
# Total municipality processed 19run 3147907
# Total municipality processed 20run 3144805
# Total municipality processed 21run 3157807
# Total municipality processed 22run 3171204
# Total municipality processed 23run 3122306
# Total municipality processed 24run 3113404
# Total municipality processed 25run 3137601
# Total municipality processed 26run 3167202
# Total municipality processed 27run 3119401
# Total municipality processed 28run 3130101
# Total municipality processed 29run 3127701
# Total municipality processed 30run 3149309
# Total municipality processed 31run 3129806
# Total municipality processed 32run 3104007
# Total municipality processed 33run 3142106
# Total municipality processed 34run 3102001
# [1] "Removed too many columns"
# run 3157005
# Total municipality processed 36run 3168606
# Total municipality processed 37run 3111408
# Total municipality processed 38run 3133402
# Total municipality processed 39run 3114550
# Total municipality processed 40run 3170438
# Total municipality processed 41run 3138625
# Total municipality processed 42run 3116902
# [1] "Removed too many columns"
# run 3134400
# Total municipality processed 44run 3161304
# Total municipality processed 45run 3147105
# Total municipality processed 46run 3127107
# Total municipality processed 47run 3137007
# [1] "Removed too many columns"
# run 3169406
# Total municipality processed 49run 3144904
# [1] "Removed too many columns"
# run 3117702
# [1] "Removed too many columns"
# run 3169307
# Total municipality processed 52run 3170701
# Total municipality processed 53run 3162955
# Total municipality processed 54run 3122900
# [1] "Removed too many columns"
# run 3138005
# [1] "Removed too many columns"
# run 3138401
# Total municipality processed 57run 3101508
# Total municipality processed 58run 3160009
# [1] "Removed too many columns"
# run 3104601
# Total municipality processed 60run 3154705
# Total municipality processed 61run 3152105
# Total municipality processed 62run 3155801
# Total municipality processed 63run 3100401
# [1] "Removed too many columns"
# run 3138203
# Total municipality processed 65run 3158300
# [1] "Removed too many columns"
# run 3128402
# Total municipality processed 67run 3169901
# Total municipality processed 68run 3159605
# Total municipality processed 69run 3139904
# [1] "Removed too many columns"
# run 3132404
# Total municipality processed 71run 3141009
# Total municipality processed 72run 3134905
# [1] "Removed too many columns"
# run 3152501
# Total municipality processed 74run 3103504
# Total municipality processed 75run 3162708
# [1] "Removed too many columns"
# run 3146909
# Total municipality processed 77run 3151602
# Total municipality processed 78run 3117306
# Total municipality processed 79run 3170206
# Total municipality processed 80run 3102605
# Total municipality processed 81run 3147006
# Total municipality processed 82run 3127339
# Total municipality processed 83run 3134202
# Total municipality processed 84run 3148103
# Total municipality processed 85run 3138682
# [1] "Removed too many columns"
# run 3136207
# Total municipality processed 87run 3104304
# [1] "Removed too many columns"
# run 3107406
# Total municipality processed 89run 3135100
# Total municipality processed 90run 3145208
# Total municipality processed 91run 3114303
# Total municipality processed 92run 3111101
# Total municipality processed 93

# %%
# Some discarded municipalities' IBGE code
res_all$skipped
# Out:
#  [1] "3150406" "3102001" "3116902" "3137007" "3144904" "3117702" "3122900"
#  [8] "3138005" "3160009" "3100401" "3158300" "3139904" "3134905" "3162708"
# [15] "3138682" "3104304"

# %%
mem_all <- res_all$res %>%
  discard(is.null) %>%
  bind_rows() %>%
  arrange(ibge, data_iniSE)

# %%
head(mem_all, 5)
# Out:
#   data_iniSE casos pop   nivel ibge    rate_pop week season season_start
# 1 2010-08-01 1     35401 1     3101508 2.824779 30   2011   2010-08-01
# 2 2010-08-08 3     35401 1     3101508 8.474337 31   2011   2010-08-01
# 3 2010-08-15 0     35401 1     3101508 0.000000 32   2011   2010-08-01
# 4 2010-08-22 0     35401 1     3101508 0.000000 33   2011   2010-08-01
# 5 2010-08-29 0     35401 1     3101508 0.000000 34   2011   2010-08-01
#   t_in_season mem_status
# 1 1           endemic
# 2 2           endemic
# 3 3           endemic
# 4 4           endemic
# 5 5           endemic

# %% [markdown]
# ## Plot (save in HTML later)

# %%
mem_all_clean <- mem_all %>%
  mutate(ibge = as.factor(ibge),
  data_iniSE = as.Date(data_iniSE)) %>%
  arrange(ibge, data_iniSE)

ibges <- sort(unique(mem_all_clean$ibge))

# make manual the ticks date
date_range  <- range(mem_all_clean$data_iniSE, na.rm = TRUE)
month_vals  <- seq(
  from = as.Date(format(date_range[1], "%Y-%m-01")),
  to   = as.Date(format(date_range[2], "%Y-%m-01")),
  by   = "6 month"
)
month_text  <- format(month_vals, "%Y-%m")  # labels like 2015-03

# Make the plot
p <- plot_ly()

for (i in seq_along(ibges)) {
  df_i <- mem_all_clean %>% filter(ibge == ibges[i])

  col_vec <- ifelse(df_i$mem_status %in% c("epi", "outbreak"),
                    "red", "green")

  p <- add_bars(
    p,
    data    = df_i,
    x       = ~data_iniSE,
    y       = ~rate_pop,
    name    = as.character(ibges[i]),
    visible = if (i == 1) TRUE else FALSE,
    marker  = list(color = col_vec)
  )
}

# Dropdown button
buttons <- lapply(seq_along(ibges), function(i) {
  list(
    method = "update",
    args = list(
      list(visible = seq_along(ibges) == i),
      list(title   = paste("Dengue Rate - IBGE", ibges[i]))
    ),
    label = as.character(ibges[i])
  )
})

p <- layout(
  p,
  title = paste("Dengue Rate - IBGE", ibges[1]),
  xaxis = list(
    title        = "Epidemic week",
    type         = "date",
    tickvals     = month_vals,   # monthly ticks as computed above
    ticktext     = month_text,
    tickangle    = -45,
    showgrid     = TRUE,
    gridcolor    = "rgba(0,0,0,0.15)",  # light grey
    gridwidth    = 1,
    zeroline     = FALSE
  ),
  yaxis = list(
    title     = "Rate per 100k pop",
    showgrid  = TRUE,
    gridcolor = "rgba(0,0,0,0.1)",
    zeroline  = FALSE
  ),
  updatemenus = list(
    list(
      type       = "dropdown",
      direction  = "down",
      x          = 0.02,
      xanchor    = "left",
      y          = 1.15,
      yanchor    = "top",
      active     = 0,
      buttons    = buttons,
      showactive = TRUE
    )
  )
)

# Save to HTML
saveWidget(p, "mem_ibge_dropdown.html", selfcontained = TRUE)

# %%
# focusing on 2022 years onwards (the year of the intererst)
mem_2022 <- mem_all %>%
  mutate(
    ibge      = as.factor(ibge),
    data_iniSE = as.Date(data_iniSE)
  ) %>%
  filter(data_iniSE >= as.Date("2022-01-01")) %>%   # only 2022+
  arrange(ibge, data_iniSE)

ibges <- sort(unique(mem_2022$ibge))

date_range  <- range(mem_2022$data_iniSE, na.rm = TRUE)
month_vals  <- seq(
  from = as.Date("2022-01-01"),
  to   = as.Date(format(date_range[2], "%Y-%m-01")),
  by   = "6 months"
)
month_text  <- format(month_vals, "%Y-%m")

p <- plot_ly()

for (i in seq_along(ibges)) {
  df_i <- mem_2022 %>% filter(ibge == ibges[i])

  col_vec <- ifelse(df_i$mem_status %in% c("epi", "outbreak"),
                    "red", "green")

  p <- add_bars(
    p,
    data    = df_i,
    x       = ~data_iniSE,
    y       = ~rate_pop,
    name    = as.character(ibges[i]),
    visible = if (i == 1) TRUE else FALSE,
    marker  = list(color = col_vec)
  )
}

buttons <- lapply(seq_along(ibges), function(i) {
  list(
    method = "update",
    args = list(
      list(visible = seq_along(ibges) == i),
      list(title   = paste("Dengue Rate (2022 - 2025) - IBGE", ibges[i]))
    ),
    label = as.character(ibges[i])
  )
})

p <- layout(
  p,
  title = paste("Dengue Rate (>=2022) - IBGE", ibges[1]),
  xaxis = list(
    title        = "Epidemic week",
    type         = "date",
    range        = c(as.Date("2022-01-01"), date_range[2]),
    tickvals     = month_vals,
    ticktext     = month_text,
    tickangle    = -45,
    showgrid     = TRUE,
    gridcolor    = "rgba(0,0,0,0.15)",
    gridwidth    = 1,
    zeroline     = FALSE
  ),
  yaxis = list(
    title     = "Rate per 100k pop",
    showgrid  = TRUE,
    gridcolor = "rgba(0,0,0,0.1)",
    zeroline  = FALSE
  ),
  updatemenus = list(
    list(
      type       = "dropdown",
      direction  = "down",
      x          = 0.02,
      xanchor    = "left",
      y          = 1.15,
      yanchor    = "top",
      active     = 0,
      buttons    = buttons,
      showactive = TRUE
    )
  )
)

saveWidget(p, "mem_ibge_dropdown_2022.html", selfcontained = TRUE)

# %% [markdown]
# ## Export

# %%
write_csv(mem_all, "MEM_classification_MG.csv")

# %%
drive_upload(
  media = "MEM_classification_MG.csv",
  name  = "MEM_classification_MG.csv",
  path  = as_id("1wgPvGUXoYvL4iD-jZkO4pxrN48dJDSLa"),
  overwrite = TRUE
)
# Out:
# File trashed:
#
# • MEM_classification_MG.csv <id: 10fJkmIdHS5O15HUBSbsByzEobdabaL8N>
#
# Local file:
#
# • MEM_classification_MG.csv
#
# Uploaded into Drive file:
#
# • MEM_classification_MG.csv <id: 1eXLtQFYdbTnJ4GSC2pue3Uzm5JE0RA2c>
#
# With MIME type:
#
# • text/csv
