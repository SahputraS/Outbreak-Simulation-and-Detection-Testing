# %% [markdown]
# <a href="https://colab.research.google.com/github/SahputraS/Outbreak-Simulation-and-Detection-Testing/blob/main/InfoDengue_vs_Genomic_SP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geobr
# !pip install unidecode
# !pip install rapidfuzz
# Out:
# Collecting geobr
#   Downloading geobr-0.2.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting geopandas<=1.1,>=1.0.0 (from geobr)
#   Downloading geopandas-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting shapely<=2.1.0,>=1.7.0 (from geobr)
#   Downloading shapely-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /usr/local/lib/python3.12/dist-packages (from geobr) (2.32.4)
# Requirement already satisfied: lxml<6.0.0,>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from geobr) (5.4.0)
# Requirement already satisfied: html5lib==1.1 in /usr/local/lib/python3.12/dist-packages (from geobr) (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib==1.1->geobr) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib==1.1->geobr) (0.5.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas<=1.1,>=1.0.0->geobr) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas<=1.1,>=1.0.0->geobr) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas<=1.1,>=1.0.0->geobr) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas<=1.1,>=1.0.0->geobr) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas<=1.1,>=1.0.0->geobr) (3.7.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas<=1.1,>=1.0.0->geobr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas<=1.1,>=1.0.0->geobr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas<=1.1,>=1.0.0->geobr) (2025.2)
# Downloading geobr-0.2.2-py3-none-any.whl (37 kB)
# Downloading geopandas-1.1.0-py3-none-any.whl (338 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.0/338.0 kB 8.2 MB/s eta 0:00:00
# Downloading shapely-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 51.9 MB/s eta 0:00:00
# Installing collected packages: shapely, geopandas, geobr
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.1.2
#     Uninstalling shapely-2.1.2:
#       Successfully uninstalled shapely-2.1.2
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.1.1
#     Uninstalling geopandas-1.1.1:
#       Successfully uninstalled geopandas-1.1.1
# Successfully installed geobr-0.2.2 geopandas-1.1.0 shapely-2.1.0
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 33.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.1

# %%
import gc

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px
import requests
import plotly.graph_objects as go

import time
from tqdm import tqdm

from geobr import read_municipality, read_state
import geopandas as gpd
import gc

from statsmodels.tsa.stattools import ccf
import statsmodels.formula.api as smf
import statsmodels.api as sm
from patsy import dmatrix
from statsmodels.gam.api import GLMGam, BSplines

from sklearn.preprocessing import StandardScaler
import seaborn as sns
from unidecode import unidecode

import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1970469778.py in <cell line: 0>()
#      13 from tqdm import tqdm
#      14
# ---> 15 from geobr import read_municipality, read_state
#      16 import geopandas as gpd
#      17 import gc
#
# ModuleNotFoundError: No module named 'geobr'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Import GISAID Data

# %%
sero1 = pd.read_csv('/content/drive/MyDrive/GISAID/gisaid_arbo_2025_09_23_14_sp.tsv', sep='\t')
location_split = sero1['Location'].str.split(' / ', expand=True)
location_split.columns = ['Continent', 'Country', 'State', 'City']
sero1 = pd.concat([sero1, location_split], axis=1)

sero1 = sero1[['Serotype', 'Genotype','Collection date', 'City']]

sero1['ym'] = pd.to_datetime(sero1['Collection date'], errors='coerce').dt.strftime('%Y-%m')
sero1.head(3)

# %%
# Check Nan
sero1.isna().sum()

# %%
# Rename city with NaN as no-name
sero1['City'] = sero1['City'].fillna("no-name")

# Check the data without date
sero1[sero1['ym'].isna()]
# Out:
#     Serotype  Genotype Collection date                   City   ym
# 158    DENV3  Outgroup         unknown  Sao Jose do Rio Preto  NaN
# 159    DENV4  Outgroup         unknown                no-name  NaN
# 160    DENV4  Outgroup         unknown                no-name  NaN
# 161    DENV4  Outgroup         unknown                no-name  NaN
# 162    DENV4  Outgroup         unknown                no-name  NaN
# 163    DENV4  Outgroup         unknown                no-name  NaN
# 164    DENV4  Outgroup         unknown                no-name  NaN
# 501    DENV1         V            2023                no-name  NaN
# 502    DENV1         V            2023                no-name  NaN
# 503    DENV1         V            2023                no-name  NaN
# 504    DENV1         V            2023                no-name  NaN
# 505    DENV1         V            2023                no-name  NaN
# 506    DENV1         V            2023                no-name  NaN
# 507    DENV1         V            2023                no-name  NaN
# 508    DENV1         V            2023                no-name  NaN

# %%
# Drop information without month data and unknown (because aggregate data to yearly is too coarse)
sero1 = sero1.dropna(subset=['ym'])
sero1[sero1['ym'].isna()]
# Out:
# Empty DataFrame
# Columns: [Serotype, Genotype, Collection date, City, ym]
# Index: []

# %%
print("the data starts from",sero1['ym'].min(), 'to', sero1['ym'].max())
# Out:
# the data starts from 2022-01 to 2025-07

# %% [markdown]
# ## Get IBGE

# %%
def norm_name(s):
    s = str(s).strip().lower()
    s = s.replace("''", "'")
    s = s.replace(" d'oeste", " do oeste")
    s = unidecode(s)
    for ch in "-'.,":
        s = s.replace(ch, ' ')
    return ' '.join(s.split())

# %%
extra = {
    "santa barbara d'oeste": "santa barbara do oeste",
    "santa barbara d oeste": "santa barbara do oeste",
    "lencoes paulista": "lencois paulista",
    "lencois paulista": "lencois paulista",
    "franco da rocha": "franco da rocha",
    "mogi guacu": "mogi guacu",
    "mogi mirim": "mogi mirim",
    "guaruja": "guaruja",
    "jau": "jau",
    "itanhaem": "itanhaem",
    "ribeirao preto": "ribeirao preto",
    "sao jose dos campos": "sao jose dos campos",
    "sao jose do rio preto": "sao jose do rio preto",
    "sao caetano do sul": "sao caetano do sul",
    "santo andre": "santo andre",
    "sao paulo": "sao paulo",
    "sao luis do paraitinga": "sao luis do paraitinga",
}

# %%
def attach_ibge(sero_df, ref_df, city_col="City", out_col="IBGE"):

    ref_df = ref_df.copy()
    ref_df = ref_df.rename(columns=str.lower)
    ref_df["name_key"] = ref_df["name"].apply(norm_name)

    sero_df = sero_df.copy()
    sero_df["_city_norm"] = sero_df[city_col].astype(str).apply(norm_name)
    sero_df["_city_key"]  = sero_df["_city_norm"].map(extra).fillna(sero_df["_city_norm"])

    merged = sero_df.merge(ref_df[["name_key", "ibge_code", "name"]], left_on="_city_key", right_on="name_key", how="left")

    merged[out_col] = merged["ibge_code"]
    merged = merged.drop(columns=["_city_norm", "_city_key", "name_key", "ibge_code"])

    return merged

# %%
# take ibge data
mun = read_municipality(year=2020)
mun_sp = mun[mun['code_state'] == 35].copy()

ref_sp = mun_sp[['name_muni','code_muni']].drop_duplicates()
ref_sp = ref_sp.rename(columns={'name_muni':'name', 'code_muni':'ibge_code'})
ref_sp['ibge_code'] = ref_sp['ibge_code'].astype(int).astype(str)

ref_sp.head()
# Out:
#                   name ibge_code
# 3267        Adamantina   3500105
# 3268            Adolfo   3500204
# 3269             Aguaí   3500303
# 3270    Águas Da Prata   3500402
# 3271  Águas De Lindóia   3500501

# %%
sero1_ibge = attach_ibge(sero1, ref_sp)
sero1_ibge.loc[sero1_ibge['City'] == 'Sao Luis do Paraitinga', 'IBGE'] = 3550506 # Manually fix

# %%
sero1_ibge.head(3)
# Out:
#   Serotype Genotype Collection date        City       ym        name     IBGE
# 0    DENV2       II      2022-01-30  Piracicaba  2022-01  Piracicaba  3538709
# 1    DENV2       II      2022-02-05  Piracicaba  2022-02  Piracicaba  3538709
# 2    DENV2      III      2022-03-17    Tremembe  2022-03    Tremembé  3554805

# %%
sero1_ibge.isna().sum()
# Out:
# Serotype             0
# Genotype             0
# Collection date      0
# City                 0
# ym                   0
# name               342
# IBGE               341
# dtype: int64

# %%
sero1_ibge = sero1_ibge.copy()

sero1_ibge['Collection date'] = pd.to_datetime(sero1_ibge['Collection date'], errors='coerce')
sero1_ibge = sero1_ibge.dropna(subset=['Collection date', 'Serotype'])           # keep only valid rows
sero1_ibge['month'] = sero1_ibge['Collection date'].values.astype('datetime64[M]')

sero_m = (sero1_ibge.groupby(['month','Serotype'], as_index=False)
                       .size()
                       .rename(columns={'size':'n'}))

sero_mw = (sero_m.pivot(index='month', columns='Serotype', values='n')
                   .fillna(0)
                   .astype(int)
                   .sort_index())

sero_mw.head(3)
# Out:
# Serotype    DENV1  DENV2  DENV3  DENV4
# month
# 2022-01-01     13      1      0      0
# 2022-02-01     58      1      0      0
# 2022-03-01    115     11      0      0

# %%
sero_mw.tail(3)
# Out:
# Serotype    DENV1  DENV2  DENV3  DENV4
# month
# 2025-05-01      5     10      4      0
# 2025-06-01      0     20      6      0
# 2025-07-01      0     11      1      0

# %% [markdown]
# ## Import Dengue Data

# %%
def data_donwload(geocode, y_start, y_end):
  url = "https://info.dengue.mat.br/api/alertcity"
  geocode = geocode
  disease = "dengue"
  format = "csv"
  ew_start = 1
  ew_end = 53
  ey_start = y_start
  ey_end = y_end

  params =(
      "&disease="
      + f"{disease}"
      + "&geocode="
      + f"{geocode}"
      + "&disease="
      + f"{disease}"
      + "&format="
      + f"{format}"
      + "&ew_start="
      + f"{ew_start}"
      + "&ew_end="
      + f"{ew_end}"
      + "&ey_start="
      + f"{ey_start}"
      + "&ey_end="
      + f"{ey_end}"
  )

  url_resp = "?".join([url, params])

  dados = pd.read_csv(url_resp, index_col='SE')
  dados['ibge'] = geocode
  return dados

# %%
downdload_data = False # Manual switch to download data
if downdload_data == True:
  all_data = []
  y_start= 2021
  y_end = 2025
  for geocode in tqdm(codes_sp, desc="Downloading"):
      try:
          df = data_donwload(geocode, y_start=y_start, y_end=y_end)
          df['ibge'] = geocode
          all_data.append(df)
      except Exception as e:
          print(f"Failed for {geocode}: {e}")
      time.sleep(0.1)

  data_sp = pd.concat(all_data)
  data_sp.head()

  del all_data
  gc.collect()

  # Save in my drive so i don't need to redownload
  data_sp2 = data_sp[['data_iniSE', 'ibge', 'nivel', 'casos', 'pop']]
  save_path = "/content/drive/MyDrive/GISAID/data_sp_incidence.csv"
  data_sp2.to_csv(save_path, index=False)
  print(f"File saved to: {save_path}")

else:
  data_sp2 = pd.read_csv('/content/drive/MyDrive/GISAID/data_sp_incidence.csv')
  data_sp2 = data_sp2[['data_iniSE', 'ibge', 'nivel', 'casos', 'pop']]

data_sp2.head(5)
# Out:
#    data_iniSE     ibge  nivel  casos      pop
# 0  2025-09-07  3500105      1     15  34357.0
# 1  2025-08-31  3500105      1     22  34357.0
# 2  2025-08-24  3500105      1     10  34357.0
# 3  2025-08-17  3500105      1     12  34357.0
# 4  2025-08-10  3500105      1      7  34357.0

# %%
data_sp2['nivel'].unique()
# Out:
# array([1, 4, 2, 3])

# %%
# Take the municipality that is on the sero data
ibge_sp_target = sero1_ibge['IBGE'].unique()

ibge_int = (pd.to_numeric(pd.Series(ibge_sp_target), errors='coerce')
              .dropna()
              .astype(int)
              .to_numpy())
len(ibge_int)
# Out:
# 186

# %%
inc_sp = data_sp2[data_sp2['ibge'].isin(ibge_int)]
inc_sp.tail()
# Out:
#         data_iniSE     ibge  nivel  casos      pop
# 158020  2021-01-31  3557303      2      1  11407.0
# 158021  2021-01-24  3557303      1      1  11407.0
# 158022  2021-01-17  3557303      1      1  11407.0
# 158023  2021-01-10  3557303      1      0  11407.0
# 158024  2021-01-03  3557303      1      0  11407.0

# %%
len(inc_sp['ibge'].unique())
# Out:
# 186

# %%
print("the data starts from",inc_sp['data_iniSE'].min(), 'to', inc_sp['data_iniSE'].max())
# Out:
# the data starts from 2021-01-03 to 2025-09-07

# %%
# Take the data from 2022-01 and 2025-07
inc_sp = inc_sp[(inc_sp['data_iniSE'] >= '2022-01-01') & (inc_sp['data_iniSE'] < '2025-08-01')]
print("the data starts from",inc_sp['data_iniSE'].min(), 'to', inc_sp['data_iniSE'].max())
inc_sp.tail()
# Out:
# the data starts from 2022-01-02 to 2025-07-27
#         data_iniSE     ibge  nivel  casos      pop
# 157968  2022-01-30  3557303      1      0  11407.0
# 157969  2022-01-23  3557303      1      0  11407.0
# 157970  2022-01-16  3557303      1      0  11407.0
# 157971  2022-01-09  3557303      1      1  11407.0
# 157972  2022-01-02  3557303      1      1  11407.0

# %% [markdown]
# ### Aggregate Info Dengue

# %%
# Simple method
inc_sp = inc_sp.copy()
inc_sp['month'] = pd.to_datetime(inc_sp['data_iniSE']).values.astype('datetime64[M]')

inc_sp = inc_sp.copy()

inc_sp['nivel2'] = inc_sp['nivel'].astype('object')

m1 = (inc_sp['nivel'] == 1) & (inc_sp['casos'] == 0)   # green & zero cases
m2 = (inc_sp['nivel'] == 1) & (inc_sp['casos']  > 0)   # green & some cases

inc_sp.loc[m1, 'nivel2'] = 'non_case'
inc_sp.loc[m2, 'nivel2'] = 'endemic'

nivel_c = (inc_sp.groupby(['month','nivel2'], as_index=False)
                 .size()
                 .rename(columns={'size':'n_rows'}))

nivel_cw = nivel_c.pivot(index='month', columns='nivel2', values='n_rows').fillna(0).astype(int)
nivel_cw['alarm'] = nivel_cw[2]+ nivel_cw[3]+nivel_cw[4] # Combine the 2,3,4 alert level into just 'alarm'
nivel_cw.drop(columns=[2,3,4], inplace=True)

nivel_cw = nivel_cw.copy()
nivel_cw.index = pd.to_datetime(nivel_cw.index)

# Convert to percentage
nivel_perc = nivel_cw.div(nivel_cw.sum(axis=1), axis=0).mul(100)
nivel_perc.tail(3)
# Out:
# nivel2        endemic   non_case      alarm
# month
# 2025-05-01  29.704301   4.301075  65.994624
# 2025-06-01  60.645161  12.580645  26.774194
# 2025-07-01  74.865591  22.177419   2.956989

# %%
nivel_perc.head(3)
# Out:
# nivel2        endemic   non_case      alarm
# month
# 2022-01-01  46.344086  24.193548  29.462366
# 2022-02-01  42.069892  20.161290  37.768817
# 2022-03-01  33.198925   7.795699  59.005376

# %%
## Recheck if the sum is 100

row_sums = nivel_perc.sum(axis=1, skipna=True)
ok = np.isclose(row_sums.to_numpy(), 100.0, atol=1e-6)
ok_all = bool(np.all(ok))
ok_all
# Out:
# True

# %%
# nivel_perc_plot = nivel_perc.copy()
# nivel_perc_plot.columns = nivel_perc_plot.columns.map(str)
# nivel_perc_plot['month'] = nivel_perc_plot.index
# df_long = nivel_perc_plot.melt(id_vars='month', var_name='nivel', value_name='percent')

# fig = px.area(
#     df_long,
#     x='month', y='percent', color='nivel',
#     category_orders={'nivel': ['endemic','non_case','2','3','4']},
#     labels={'percent':'Proportion (%)', 'month':'Month', 'nivel':'nivel'},
#     title='Monthly proportion of the labels'
# )

# fig.update_layout(
#     template='plotly_white',
#     hovermode='x unified',

#     title=dict(text='Monthly proportion of the labels', font=dict(size=28)),
#     font=dict(size=16),
#     legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='left', x=0,
#                 title_text='nivel', font=dict(size=18)),
#     hoverlabel=dict(font_size=14))


# fig.update_xaxes(title_text='Month',
#                  title_font=dict(size=20),
#                  tickfont=dict(size=18))
# fig.update_yaxes(title_text='Proportion (%)',
#                  title_font=dict(size=20),
#                  tickfont=dict(size=18),
#                  range=[0,100], ticksuffix='%')

# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5aecbef8-1f7e-439b-b6a3-52e426ec39f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5aecbef8-1f7e-439b-b6a3-52e426ec39f4")) {                    Plotly.newPlot(                        "5aecbef8-1f7e-439b-b6a3-52e426ec39f4",                        [{"fillpattern":{"shape":""},"hovertemplate":"nivel=endemic\u003cbr\u003eMonth=%{x}\u003cbr\u003eProportion (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"endemic","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"endemic","orientation":"v","showlegend":true,"stackgroup":"1","x":["2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00","2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00"],"xaxis":"x","y":[46.344086021505376,42.06989247311828,33.19892473118279,35.215053763440864,39.56989247311828,71.63978494623656,78.92473118279571,77.41935483870968,72.44623655913979,69.89247311827957,68.27956989247312,43.54838709677419,46.45161290322581,31.317204301075268,22.446236559139784,35.913978494623656,46.63978494623656,71.23655913978494,68.27956989247312,69.48924731182797,68.41397849462365,61.505376344086024,64.38172043010752,41.39784946236559,32.66129032258064,20.698924731182796,15.483870967741936,16.397849462365592,23.521505376344088,36.666666666666664,63.844086021505376,72.31182795698925,72.25806451612902,66.8010752688172,65.45698924731182,45.376344086021504,25.940860215053764,8.60215053763441,9.56989247311828,19.22043010752688,29.70430107526882,60.64516129032258,74.86559139784946],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"nivel=non_case\u003cbr\u003eMonth=%{x}\u003cbr\u003eProportion (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"non_case","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"non_case","orientation":"v","showlegend":true,"stackgroup":"1","x":["2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00","2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00"],"xaxis":"x","y":[24.193548387096776,20.1612903225806 ...

# %% [markdown]
# ## Import the Epi-Quark

# %%
try:
    from epiquark import conf_matrix, score, timeliness
except ImportError:
    import sys
    # !{sys.executable} -m pip install git+https://github.com/aauss/epi-quark.git
    from epiquark import conf_matrix, score, timeliness
# Out:
# Collecting git+https://github.com/aauss/epi-quark.git
#   Cloning https://github.com/aauss/epi-quark.git to /tmp/pip-req-build-srfhb70l
#   Running command git clone --filter=blob:none --quiet https://github.com/aauss/epi-quark.git /tmp/pip-req-build-srfhb70l
#   Resolved https://github.com/aauss/epi-quark.git to commit 9e6ca56145f63730b2a62dc2b93191f9884e3c39
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from epi-quark==0.1.0) (1.6.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from epi-quark==0.1.0) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->epi-quark==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->epi-quark==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->epi-quark==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->epi-quark==0.1.0) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.2->epi-quark==0.1.0) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.2->epi-quark==0.1.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.2->epi-quark==0.1.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->epi-quark==0.1.0) (1.17.0)
# Building wheels for collected packages: epi-quark
#   Building wheel for epi-quark (pyproject.toml) ... done
#   Created wheel for epi-quark: filename=epi_quark-0.1.0-py3-none-any.whl size=13005 sha256=a05b337fefc86cc4e770e01bb1837ee9dc3d912477c0ed8e39a88ef570732a2c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oq4uftct/wheels/ca/e2/d7/40d6b6b9b7873b820dbb0f3833f59fa5fac00f237710b2069b
# Successfully built epi-quark
# Installing collected packages: epi-quark
# Successfully installed epi-quark-0.1.0

# %% [markdown]
# Reformat the serotype data

# %%
sero_mw['endemic'] = 0 # Add endemic category
sero_mw.tail(3)
# Out:
# Serotype    DENV1  DENV2  DENV3  DENV4  endemic
# month
# 2025-05-01      5     10      4      0        0
# 2025-06-01      0     20      6      0        0
# 2025-07-01      0     11      1      0        0

# %%
# Check if the time step are complete (all months exists)
full = pd.date_range(sero_mw.index.min(), sero_mw.index.max(), freq='MS')

missing_months = full.difference(sero_mw.index)
is_complete = len(missing_months) == 0

print(f"Complete monthly series: {is_complete}")
if not is_complete:
    print("Missing months:", missing_months.strftime('%Y-%m').tolist())
# Out:
# Complete monthly series: False
# Missing months: ['2022-09', '2022-10', '2022-11', '2022-12', '2024-08', '2024-09']

# %%
sero_mw2 = sero_mw.reindex(full, fill_value=0)
sero_mw2.index.name = 'month'

# %%
sero_ml = (sero_mw2.reset_index()  # bring month out of the index, and make into long format
                    .melt(id_vars='month',
                          var_name='Serotype',
                          value_name='value')
                    .sort_values(['month','Serotype'])
                    .reset_index(drop=True))

sero_ml.rename(columns={'Serotype': 'data_label'}, inplace=True)

sero_ml.tail()
# Out:
#          month data_label  value
# 210 2025-07-01      DENV1      0
# 211 2025-07-01      DENV2     11
# 212 2025-07-01      DENV3      1
# 213 2025-07-01      DENV4      0
# 214 2025-07-01    endemic      0

# %% [markdown]
# Reformat the signal data

# %%
# Check if the time step are complete (all months exists)
nivel_perc.index= pd.to_datetime(nivel_perc.index)
full = pd.date_range(nivel_perc.index.min(), nivel_perc.index.max(), freq='MS')

missing_months = full.difference(nivel_perc.index)
is_complete = len(missing_months) == 0

print(f"Complete monthly series: {is_complete}")
if not is_complete:
    print("Missing months:", missing_months.strftime('%Y-%m').tolist())
# Out:
# Complete monthly series: True

# %%
nivel_ml = (nivel_perc.reset_index()  # bring month out of the index and make to long format
                    .melt(id_vars='month',
                          var_name='nivel2',
                          value_name='value')
                    .sort_values(['month','nivel2'])
                    .reset_index(drop=True))

nivel_ml.rename(columns={'nivel2': 'signal_label'}, inplace=True)
nivel_ml['value'] = nivel_ml['value']/100 # Make to decimal

nivel_ml.tail(6)
# Out:
#          month signal_label     value
# 123 2025-06-01        alarm  0.267742
# 124 2025-06-01      endemic  0.606452
# 125 2025-06-01     non_case  0.125806
# 126 2025-07-01        alarm  0.029570
# 127 2025-07-01      endemic  0.748656
# 128 2025-07-01     non_case  0.221774

# %% [markdown]
# **Epi-Quark**

# %%
cases = sero_ml
signals = nivel_ml
dl = sero_ml['data_label'].unique()
disease_list = np.concatenate([dl, ['non_case']])

# %%
cases.head(5)
# Out:
#        month data_label  value
# 0 2022-01-01      DENV1     13
# 1 2022-01-01      DENV2      1
# 2 2022-01-01      DENV3      0
# 3 2022-01-01      DENV4      0
# 4 2022-01-01    endemic      0

# %%
signals.head(6)
# Out:
#        month signal_label     value
# 0 2022-01-01        alarm  0.294624
# 1 2022-01-01      endemic  0.463441
# 2 2022-01-01     non_case  0.241935
# 3 2022-02-01        alarm  0.377688
# 4 2022-02-01      endemic  0.420699
# 5 2022-02-01     non_case  0.201613

# %%
metrics_epi_quark = {
    "precision": score(cases, signals, "precision", 0.2, 0.2),
    "recall": score(cases, signals, "recall", 0.2, 0.2),
    "f1": score(cases, signals, "f1", 0.2, 0.2),
}

epi_quark_df = pd.DataFrame(metrics_epi_quark, index=disease_list)
epi_quark_df = epi_quark_df.round(2)
epi_quark_df
# Out:
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py:177: FutureWarning:
#
# The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py:177: FutureWarning:
#
# The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#
# /usr/local/lib/python3.12/dist-packages/epiquark/api.py:180: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# /usr/local/lib/python3.12/dist-packages/epiquark/api.py:180: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py:177: FutureWarning:
#
# The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#           precision  recall    f1
# DENV1          0.75    0.10  0.17
# DENV2          0.75    0.18  0.29
# DENV3          0.25    0.17  0.20
# DENV4          0.00     NaN  0.00
# endemic        0.00     NaN  0.00
# non_case       0.29    0.67  0.40

# %% [markdown]
# **In the example case where there is no non-case (non_case label has 0 occurences in cases and signal dataframes)**

# %%
ser_cols = ['DENV1','DENV2','DENV3','DENV4', 'endemic']

df = sero_mw2.copy()
mask = (df[ser_cols] == 0)

# Fill random number between 1 to 10 on where it is 0s on the denv 1,2,3,4 and endemic (therefore non_case is 0)
rng = np.random.default_rng(22)
rand_vals = pd.DataFrame(
    rng.integers(1, 10, size=df[ser_cols].shape),
    index=df.index, columns=ser_cols
)
df.loc[:, ser_cols] = df[ser_cols].where(~mask, rand_vals)

df.head(3)
# Out:
# Serotype    DENV1  DENV2  DENV3  DENV4  endemic
# month
# 2022-01-01     13      1      6      2        9
# 2022-02-01     58      1      6      1        5
# 2022-03-01    115     11      3      8        3

# %%
df['non_case'] = 0
df.head(5)
# Out:
# Serotype    DENV1  DENV2  DENV3  DENV4  endemic  non_case
# month
# 2022-01-01     13      1      6      2        9         0
# 2022-02-01     58      1      6      1        5         0
# 2022-03-01    115     11      3      8        3         0
# 2022-04-01     97      6      1      3        5         0
# 2022-05-01     49      1      5      1        4         0

# %%
test_df = (df.reset_index()  # bring month out of the index, and make into long format
                    .melt(id_vars='month',
                          var_name='Serotype',
                          value_name='value')
                    .sort_values(['month','Serotype'])
                    .reset_index(drop=True))

test_df.rename(columns={'Serotype': 'data_label'}, inplace=True)
test_df.tail()
# Out:
#          month data_label  value
# 253 2025-07-01      DENV2     11
# 254 2025-07-01      DENV3      1
# 255 2025-07-01      DENV4      5
# 256 2025-07-01    endemic      2
# 257 2025-07-01   non_case      0

# %%
sig_test = nivel_perc.copy()
# Make another alarm label for a place holder of original non_case values
# This is to keep the total is 100%

sig_test['alarm1'] = sig_test['non_case']
sig_test['non_case'] = 0 #therefore non_case is 0
sig_test.head(3)
# Out:
# nivel2        endemic  non_case      alarm     alarm1
# month
# 2022-01-01  46.344086         0  29.462366  24.193548
# 2022-02-01  42.069892         0  37.768817  20.161290
# 2022-03-01  33.198925         0  59.005376   7.795699

# %%
sig_test2 = (sig_test.reset_index()  # bring month out of the index and make to long format
                    .melt(id_vars='month',
                          var_name='nivel2',
                          value_name='value')
                    .sort_values(['month','nivel2'])
                    .reset_index(drop=True))

sig_test2.rename(columns={'nivel2': 'signal_label'}, inplace=True)
sig_test2['value'] = sig_test2['value']/100 # Make to decimal

sig_test2.tail(6)
# Out:
#          month signal_label     value
# 166 2025-06-01      endemic  0.606452
# 167 2025-06-01     non_case  0.000000
# 168 2025-07-01        alarm  0.029570
# 169 2025-07-01       alarm1  0.221774
# 170 2025-07-01      endemic  0.748656
# 171 2025-07-01     non_case  0.000000

# %%
cases2 = test_df
signals2 = sig_test2
dl2 = cases2['data_label'].unique()
disease_list = np.concatenate([dl2, ['non_case']])

# %%
print('Check if cases dataframe contains all non-zero values (therefore non_case is 0) : ', np.all(cases2['value'] > 0))
print('Check if signal data, label "non_case", contains all zero values : ', np.all((signals2[signals2['signal_label'] == 'non_case']['value']) == 0.0))
# Out:
# Check if cases dataframe contains all non-zero values (therefore non_case is 0) :  False
# Check if signal data, label "non_case", contains all zero values :  True

# %%
# Data from Jan-22 to July-25, therefore 43 months
# The cases dataframe should have 5 labels (i.e. DENV1,2,3,4, endemic)
# Therefore should exists 5 x 43 data points

print('The length of cases dataset is as expected:', len(cases2)==5*43)

# Data from Jan-22 to July-25, therefore 43 months
# The cases dataframe should have 4 labels (i.e. alarm, alarm1 endemic, non_case)
# Therefore should exists 4 x 43 data points

print('The length of cases dataset is as expected:', len(signals2)==4*43)
# Out:
# The length of cases dataset is as expected: False
# The length of cases dataset is as expected: True

# %%
# When both signal and cases have non-zero of non-case, the evaluator crash
metrics_epi_quark2 = {
    "precision": score(cases2, signals2, "precision", 0.2, 0.2),
    "recall": score(cases2, signals2, "recall", 0.2, 0.2),
    "f1": score(cases2, signals2, "f1", 0.2, 0.2),
}

epi_quark_df2 = pd.DataFrame(metrics_epi_quark2, index=disease_list2)
epi_quark_df2 = epi_quark_df2.round(2)
epi_quark_df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2499917869.py in <cell line: 0>()
#       1 # When both signal and cases have non-zero of non-case, the evaluator crash
#       2 metrics_epi_quark2 = {
# ----> 3     "precision": score(cases2, signals2, "precision", 0.2, 0.2),
#       4     "recall": score(cases2, signals2, "recall", 0.2, 0.2),
#       5     "f1": score(cases2, signals2, "f1", 0.2, 0.2),
#
# /usr/local/lib/python3.12/dist-packages/epiquark/api.py in score(cases, signals, metric, threshold_true, threshold_pred, weighting, time_space_weighting, time_axis)
#     131         "mae": sk_metrics.mean_absolute_error,
#     132     }
# --> 133     return ScoreCalculator(cases, signals).calc_score(
#     134         scorer=metrics[metric],
#     135         p_thresh=threshold_true,
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py in __init__(self, cases, signals)
#     259                 the coordinate system of the cases DataFrame are ignored.
#     260         """
# --> 261         super().__init__(cases, signals)
#     262
#     263     def calc_score(
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py in __init__(self, cases, signals)
#     157
#     158     def __init__(self, cases, signals) -> None:
# --> 159         super().__init__(cases, signals)
#     160
#     161     def _eval_df(self) -> pd.DataFrame:
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py in __init__(self, cases, signals)
#      16         self.MUST_HAVE_LABELS = {"endemic", "non_case"}
#      17         self.COORDS = self._extract_coords(cases)
# ---> 18         self.cases = self._prepare_cases(cases)
#      19         self.signals = self._check_signals_correctness(signals, self.cases)
#      20         self.SIGNALS_LABELS = self.signals["signal_label"].unique()
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py in _prepare_cases(self, cases)
#      25
#      26     def _prepare_cases(self, cases: pd.DataFrame) -> pd.DataFrame:
# ---> 27         cases_correct = self._check_cases_correctness(cases)
#      28         return self._impute_non_case(cases_correct)
#      29
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py in _check_cases_correctness(self, cases)
#      30     def _check_cases_correctness(self, cases: pd.DataFrame) -> pd.DataFrame:
#      31         self._check_no_nans_exist(cases)
# ---> 32         self._check_non_cases_not_included(cases)
#      33         self._check_endemic_exists(cases)
#      34         self._check_cases_pos_ints(cases)
#
# /usr/local/lib/python3.12/dist-packages/epiquark/scorer.py in _check_non_cases_not_included(self, cases)
#      42     def _check_non_cases_not_included(self, cases) -> None:
#      43         if "non_case" in cases["data_label"].values:
# ---> 44             raise ValueError(
#      45                 (
#      46                     "Please remove entries with label 'non_cases' from cases DataFrame. "
#
# ValueError: Please remove entries with label 'non_cases' from cases DataFrame. This label is included automatically and therefore internally reserved.
